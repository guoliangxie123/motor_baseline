# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(style="ticks")
plt.rcParams['font.family'] = 'SimHei'
plt.rcParams['axes.unicode_minus']=False

# %%
iris['冷压输送'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris = sns.load_dataset("iris")
cls = ['隔膜放卷','极片放卷','转塔卷绕','冷压','机器工况']
iris.columns = cls
iris['机器工况'][iris['机器工况'] == 'setosa' ] = '平稳运行'
iris['机器工况'][iris['机器工况'] == 'versicolor' ] = '报警警告'
iris['机器工况'][iris['机器工况'] == 'virginica'] = '故障停机'
# Out:
# C:\Users\1212214\AppData\Local\Temp\ipykernel_7488\1625669786.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris['机器工况'][iris['机器工况'] == 'setosa' ] = '平稳运行'
# C:\Users\1212214\AppData\Local\Temp\ipykernel_7488\1625669786.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iris['机器工况'][iris['机器工况'] == 'versicolor' ] = '报警警告'
# C:\Users\1212214\AppData\Local\Temp\ipykernel_7488\1625669786.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
iris
# Out:
#      隔膜放卷  极片放卷  转塔卷绕   冷压  机器工况
# 0     5.1   3.5   1.4  0.2  平稳运行
# 1     4.9   3.0   1.4  0.2  平稳运行
# 2     4.7   3.2   1.3  0.2  平稳运行
# 3     4.6   3.1   1.5  0.2  平稳运行
# 4     5.0   3.6   1.4  0.2  平稳运行
# ..    ...   ...   ...  ...   ...
# 145   6.7   3.0   5.2  2.3  故障停机
# 146   6.3   2.5   5.0  1.9  故障停机
# 147   6.5   3.0   5.2  2.0  故障停机
# 148   6.2   3.4   5.4  2.3  故障停机
# 149   5.9   3.0   5.1  1.8  故障停机
#
# [150 rows x 5 columns]

# %%
# iris
g = sns.pairplot(iris,hue="机器工况",palette="Set2", diag_kind="kde", height=2.5)
